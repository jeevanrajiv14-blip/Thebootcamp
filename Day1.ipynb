# %%
text = "Python is very easy"

print("Original string:")
print(text)

print("\nString in reverse:")
print(text[::-1])

print("\nWords in reverse order:")
words = text.split()
print(" ".join(words[::-1]))
# Out:
# Original string:
# Python is very easy
#
# String in reverse:
# ysae yrev si nohtyP
#
# Words in reverse order:
# easy very is Python

# %%
import random

numbers = [random.randint(1, 100) for _ in range(10)]

print("List of random numbers:")
print(numbers)

print("Even numbers:")
for number in numbers:
    if number % 2 == 0:
        print(number)
# Out:
# List of random numbers:
# [92, 93, 6, 96, 36, 43, 84, 23, 60, 53]
# Even numbers:
# 92
# 6
# 96
# 36
# 84
# 60
